# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import cv2 as cv
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.mixed_precision import set_global_policy
# Out:
# 2025-10-24 17:32:37.398289: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-24 17:32:37.996110: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Enable mixed precision training to optimize GPU memory usage
set_global_policy('mixed_float16')

# %%
# Define Paths
data_path = '../data/ISIC_2019_Training_Input'
csv_path = '../data/ISIC_2019_Training_GroundTruth.csv'

# %%
# Load metadata
df = pd.read_csv(csv_path)

# %%
# Add image paths to DataFrame for easy access
df['image_path'] = df['image'].apply(lambda x: os.path.join(data_path, x + '.jpg'))

# %%
# Convert one-hot encoded labels to categorical
class_columns = ['MEL', 'NV', 'BCC', 'AK', 'BKL', 'DF', 'VASC', 'SCC', 'UNK']
df['label'] = df[class_columns].idxmax(axis=1)

# %%
#  Split data into train (70%), validation (15%) and test (15%) sets
train_df, temp_df = train_test_split(df, test_size = 0.3, stratify = df['label'], random_state = 42)
val_df, test_df = train_test_split(temp_df, test_size = 0.5, stratify = temp_df['label'], random_state = 42)
print(f"Train: {len(train_df)}, Validation: {len(val_df)}, Test: {len(test_df)}")
# Out:
# Train: 17731, Validation: 3800, Test: 3800

# %%
# Set up data augmentation for training and normalization for validation/test
train_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input,    rotation_range = 20, # Random rotation up to 20 degrees
    width_shift_range = 0.2, # Random horizontal shift
    height_shift_range = 0.2, # Random vertical shift
    horizontal_flip = True, # Random horizontal flip
    zoom_range = 0.2, # Random zoom
    fill_mode = 'nearest' # Fill new pixels with nearest value
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input) # Only normalize for validation/test

# Configure data generators
target_size = (224, 224) # Resize images for EfficientNetB0
batch_size = 16 

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    x_col = 'image_path',
    y_col = 'label',
    target_size = target_size,
    batch_size = batch_size,
    class_mode = 'categorical'
)

val_generator = val_test_datagen.flow_from_dataframe(
    val_df,
    x_col = 'image_path',
    y_col = 'label',
    target_size = target_size,
    batch_size = batch_size,
    class_mode = 'categorical'
)

test_generator = val_test_datagen.flow_from_dataframe(
    test_df,
    x_col = 'image_path',
    y_col = 'label',
    target_size = target_size,
    batch_size = batch_size,
    class_mode = 'categorical',
    shuffle = False # Keep test data order to evaluation   
)

print("Class indices:", train_generator.class_indices)
# Out:
# Found 17731 validated image filenames belonging to 8 classes.
# Found 3800 validated image filenames belonging to 8 classes.
# Found 3800 validated image filenames belonging to 8 classes.
# Class indices: {'AK': 0, 'BCC': 1, 'BKL': 2, 'DF': 3, 'MEL': 4, 'NV': 5, 'SCC': 6, 'VASC': 7}

# %%
# Define class weights 
class_weights = {
    'AK': 3.652, 'BCC': 0.953, 'BKL': 1.207, 'DF': 13.248,
    'MEL': 0.700, 'NV': 0.246, 'SCC': 5.042, 'VASC': 12.515
}

# %%
# Define ResNet50 model with transfer learning
def build_resnet50_model(num_classes = 8):
    # load ResNet50 with ImageNet weight exclude top layer
    base_model = ResNet50(weights = 'imagenet', include_top = False, input_shape = (224, 224, 3))
    
    # Freeze the base model layers to prevent training initially
    base_model.trainable = False

    # Build the model
    model = Sequential([
        base_model, 
        GlobalAveragePooling2D(), # Pool the feature maps to a single vector
        Dense(512, activation = 'relu'), # Add a dense layer for feature learning
        Dropout(0.5), # Add dropout to prevent overfitting
        Dense(num_classes, activation = 'softmax', dtype = 'float32') # Output layer for 8 classes
    ])


    # Map class weights to generator indices
    class_indices = {'AK': 0, 'BCC': 1, 'BKL': 2, 'DF': 3, 'MEL': 4, 'NV': 5, 'SCC': 6, 'VASC': 7}
    class_weight_dict = {class_indices[cls]: weight for cls, weight in class_weights.items()}


    # compile the model
    model.compile(
        optimizer = Adam(learning_rate = 0.001),
        loss = 'categorical_crossentropy',
        metrics = ['accuracy']
    )

    return model

# %%
model = build_resnet50_model()
# Out:
# 2025-10-24 17:32:38.851893: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-24 17:32:38.880867: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-24 17:32:38.884605: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-24 17:32:38.888487: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-24 17:32:38.891932: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-24 17:32:38.895182: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-24 17:32:39.017025: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-24 17:32:39.018239: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-24 17:32:39.019331: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-10-24 17:32:39.020386: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2608 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         4,104 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,640,904 (94.00 MB)
#  Trainable params: 1,053,192 (4.02 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
# Define training parameters
epochs = 20
batch_size = 16

# %%
# Define callbacks
callbacks = [
    # stop training if val_loss doesn't improve for 5 epochs
    EarlyStopping(monitor = 'val_loss', patience = 5, restore_best_weights = True),

    # save the best model based on val_accuracy
    ModelCheckpoint('best_resnet50_model.keras', monitor = 'val_accuracy', save_best_only = True),

    # reduce learning rate if val_loss plateaus
    ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, patience = 3, min_lr = 1e-6)
]

# %%
class_weight_dict = {
    0: 3.652,  # AK
    1: 0.953,  # BCC
    2: 1.207,  # BKL
    3: 13.248, # DF
    4: 0.700,  # MEL
    5: 0.246,  # NV
    6: 5.042,  # SCC
    7: 12.515  # VASC
}

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs = epochs,
    validation_data = val_generator,
    class_weight = class_weight_dict,
    callbacks = callbacks,
    verbose = 1
)
# Out:
# /home/elnaz/anaconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761314647.968054    6578 service.cc:145] XLA service 0x72a03c001d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761314647.968076    6578 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2025-10-24 17:34:08.173682: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-24 17:34:09.029908: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
# 2025-10-24 17:34:12.017112: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 0: 0.125854, expected -nan
# 2025-10-24 17:34:12.017139: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 1: 0.232422, expected 0
# 2025-10-24 17:34:12.017146: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 2: 0.131714, expected -nan
# 2025-10-24 17:34:12.017151: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 3: 0.187744, expected 0
# 2025-10-24 17:34:12.017156: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 4: 0.145752, expected -nan
# 2025-10-24 17:34:12.017161: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 5: 0.164062, expected 0
# 2025-10-24 17:34:12.017165: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 6: 0.130127, expected -nan
# 2025-10-24 17:34:12.017170: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 7: 0.162964, expected 0
# 2025-10-24 17:34:12.017175: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 8: 0.123474, expected -nan
# 2025-10-24 17:34:12.017180: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 9: 0.174072, expected 0
# E0000 00:00:1761314652.018821    6578 conv_algorithm_picker.cc:742] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[16,112,112,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[16,224,224,3]{3,2,1,0}, f16[64,7,7,3]{3,2,1,0}, f16[64]{0}), window={size=7x7 stride=2x2 pad=3_3x3_3}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} for eng46{} vs eng4{k2=3,k4=2,k5=3,k6=3,k7=2}
# E0000 00:00:1761314652.018843    6578 conv_algorithm_picker.cc:304] Device: NVIDIA GeForce GTX 1650
# E0000 00:00:1761314652.018845    6578 conv_algorithm_picker.cc:305] Platform: Compute Capability 7.5
# E0000 00:00:1761314652.018846    6578 conv_algorithm_picker.cc:306] Driver: 12080 (570.172.8)
# E0000 00:00:1761314652.018848    6578 conv_algorithm_picker.cc:307] Runtime: <undefined>
# E0000 00:00:1761314652.018853    6578 conv_algorithm_picker.cc:314] cudnn version: 8.9.2
# 2025-10-24 17:34:12.774801: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 0: 0.259766, expected -nan
# 2025-10-24 17:34:12.774824: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 1: 0.241089, expected 0
# 2025-10-24 17:34:12.774831: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 2: 0.256836, expected -nan
# 2025-10-24 17:34:12.774836: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 3: 0.269531, expected 0
# 2025-10-24 17:34:12.774841: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 4: 0.245972, expected -nan
# 2025-10-24 17:34:12.774846: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 5: 0.252197, expected 0
# 2025-10-24 17:34:12.774851: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 6: 0.280762, expected -nan
# 2025-10-24 17:34:12.774856: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 7: 0
E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 9: 1.39648, expected 0
# E0000 00:00:1761315042.414693    6578 conv_algorithm_picker.cc:742] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[8,7,7,2048]{3,2,1,0}, u8[0]{0}) custom-call(f16[8,7,7,512]{3,2,1,0}, f16[2048,1,1,512]{3,2,1,0}, f16[2048]{0}), window={size=1x1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} for eng39{k25=0} vs eng4{k2=3,k4=2,k5=3,k6=3,k7=2}
# E0000 00:00:1761315042.414702    6578 conv_algorithm_picker.cc:304] Device: NVIDIA GeForce GTX 1650
# E0000 00:00:1761315042.414704    6578 conv_algorithm_picker.cc:305] Platform: Compute Capability 7.5
# E0000 00:00:1761315042.414705    6578 conv_algorithm_picker.cc:306] Driver: 12080 (570.172.8)
# E0000 00:00:1761315042.414706    6578 conv_algorithm_picker.cc:307] Runtime: <undefined>
# E0000 00:00:1761315042.414709    6578 conv_algorithm_picker.cc:314] cudnn version: 8.9.2
# 2025-10-24 17:40:42.727199: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 0: 5.10156, expected -nan
# 2025-10-24 17:40:42.727220: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 1: 5.10938, expected 0
# 2025-10-24 17:40:42.727224: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 2: 5.10156, expected -nan
# 2025-10-24 17:40:42.727228: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 3: 5.31641, expected 0
# 2025-10-24 17:40:42.727232: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 4: 5.17188, expected -nan
# 2025-10-24 17:40:42.727235: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 5: 5.0625, expected 0
# 2025-10-24 17:40:42.727238: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 6: 5.12109, expected -nan
# 2025-10-24 17:40:42.727242: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 7: 5.08594, expected 0
# 2025-10-24 17:40:42.727245: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 8: 5.15625, expected -nan
# 2025-10-24 17:40:42.727249: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 9: 5.14844, expected 0
# E0000 00:00:1761315042.727253    6578 conv_algorithm_picker.cc:742] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[8,7,7,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[8,7,7,2048]{3,2,1,0}, f16[512,1,1,2048]{3,2,1,0}, f16[512]{0}), window={size=1x1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} for eng39{k25=1} vs eng4{k2=4,k4=2,k5=4,k6=3,k7=2}
# E0000 00:00:1761315042.727262    6578 conv_algorithm_picker.cc:304] Device: NVIDIA GeForce GTX 1650
# E0000 00:00:1761315042.727263    6578 conv_algorithm_picker.cc:305] Platform: Compute Capability 7.5
# E0000 00:00:1761315042.727264    6578 conv_algorithm_picker.cc:306] Driver: 12080 (570.172.8)
# E0000 00:00:1761315042.727265    6578 conv_algorithm_picker.cc:307] Runtime: <undefined>
# E0000 00:00:1761315042.727268    6578 conv_algorithm_picker.cc:314] cudnn version: 8.9.2
# 2025-10-24 17:40:42.821038: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 0: 5.10156, expected -nan
# 2025-10-24 17:40:42.821059: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 1: 5.10938, expected 0
# 2025-10-24 17:40:42.821063: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 2: 5.10156, expected -nan
# 2025-10-24 17:40:42.821067: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 3: 5.31641, expected 0
# 2025-10-24 17:40:42.821070: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 4: 5.17188, expected -nan
# 2025-10-24 17:40:42.821074: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 5: 5.0625, expected 0
# 2025-10-24 17:40:42.821077: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 6: 5.12109, expected -nan
# 2025-10-24 17:40:42.821080: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 7: 5.08594, expected 0
# 2025-10-24 17:40:42.821083: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 8: 5.15625, expected -nan
# 2025-10-24 17:40:42.821087: E external/local_xla/xla/service/gpu/buffer_comparator.cc:149] Difference at 9: 5.14844, expected 0
# E0000 00:00:1761315042.821090    6578 conv_algorithm_picker.cc:742] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f16[8,7,7,512]{3,2,1,0}, u8[0]{0}) custom-call(f16[8,7,7,2048]{3,2,1,0}, f16[512,1,1,2048]{3,2,1,0}, f16[512]{0}), window={size=1x1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} for eng39{k25=1} vs eng4{k2=3,k4=2,k5=3,k6=3,k7=2}
# E0000 00:00:1761315042.821099    6578 conv_algorithm_picker.cc:304] Device: NVIDIA GeForce GTX 1650
# E0000 00:00:1761315042.821100    6578 conv_algorithm_picker.cc:305] Platform: Compute Capability 7.5
# E0000 00:00:1761315042.821101    6578 conv_algorithm_picker.cc:306] Driver: 12080 (570.172.8)
# E0000 00:00:1761315042.821102    6578 conv_algorithm_picker.cc:307] Runtime: <undefined>
# E0000 00:00:1761315042.821104    6578 conv_algorithm_picker.cc:314] cudnn version: 8.9.2
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 402s 341ms/step - accuracy: 0.3572 - loss: 1.9505 - val_accuracy: 0.4789 - val_loss: 1.3871 - learning_rate: 0.0010
# Epoch 2/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 338s 304ms/step - accuracy: 0.4043 - loss: 1.6454 - val_accuracy: 0.5053 - val_loss: 1.3526 - learning_rate: 0.0010
# Epoch 3/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 339s 305ms/step - accuracy: 0.4208 - loss: 1.5690 - val_accuracy: 0.4861 - val_loss: 1.3311 - learning_rate: 0.0010
# Epoch 4/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 338s 305ms/step - accuracy: 0.4138 - loss: 1.5535 - val_accuracy: 0.5218 - val_loss: 1.2499 - learning_rate: 0.0010
# Epoch 5/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 338s 305ms/step - accuracy: 0.4313 - loss: 1.4995 - val_accuracy: 0.5116 - val_loss: 1.2868 - learning_rate: 0.0010
# Epoch 6/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 338s 305ms/step - accuracy: 0.4407 - loss: 1.4936 - val_accuracy: 0.4924 - val_loss: 1.3128 - learning_rate: 0.0010
# Epoch 7/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 339s 306ms/step - accuracy: 0.4474 - loss: 1.4717 - val_accuracy: 0.5300 - val_loss: 1.2482 - learning_rate: 0.0010
# Epoch 8/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 338s 305ms/step - accuracy: 0.4453 - loss: 1.4493 - val_accuracy: 0.5671 - val_loss: 1.1734 - learning_rate: 0.0010
# Epoch 9/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 336s 303ms/step - accuracy: 0.4415 - loss: 1.4567 - val_accuracy: 0.4934 - val_loss: 1.2178 - learning_rate: 0.0010
# Epoch 10/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 335s 302ms/step - accuracy: 0.4587 - loss: 1.4437 - val_accuracy: 0.4803 - val_loss: 1.3284 - learning_rate: 0.0010
# Epoch 11/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 336s 303ms/step - accuracy: 0.4587 - loss: 1.4017 - val_accuracy: 0.4942 - val_loss: 1.2803 - learning_rate: 0.0010
# Epoch 12/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 336s 303ms/step - accuracy: 0.4923 - loss: 1.2821 - val_accuracy: 0.5350 - val_loss: 1.1753 - learning_rate: 2.0000e-04
# Epoch 13/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 334s 301ms/step - accuracy: 0.5132 - loss: 1.2410 - val_accuracy: 0.5650 - val_loss: 1.1360 - learning_rate: 2.0000e-04
# Epoch 14/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 337s 304ms/step - accuracy: 0.5143 - loss: 1.2206 - val_accuracy: 0.5611 - val_loss: 1.1429 - learning_rate: 2.0000e-04
# Epoch 15/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 336s 303ms/step - accuracy: 0.5136 - loss: 1.2447 - val_accuracy: 0.5474 - val_loss: 1.1505 - learning_rate: 2.0000e-04
# Epoch 16/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 338s 305ms/step - accuracy: 0.5117 - loss: 1.2011 - val_accuracy: 0.5626 - val_loss: 1.1047 - learning_rate: 2.0000e-04
# Epoch 17/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 336s 303ms/step - accuracy: 0.5221 - loss: 1.1899 - val_accuracy: 0.5461 - val_loss: 1.1452 - learning_rate: 2.0000e-04
# Epoch 18/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 335s 302ms/step - accuracy: 0.5279 - loss: 1.1774 - val_accuracy: 0.5361 - val_loss: 1.1506 - learning_rate: 2.0000e-04
# Epoch 19/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 336s 303ms/step - accuracy: 0.5304 - loss: 1.1757 - val_accuracy: 0.5505 - val_loss: 1.1175 - learning_rate: 2.0000e-04
# Epoch 20/20
# 1109/1109 ━━━━━━━━━━━━━━━━━━━━ 337s 304ms/step - accuracy: 0.5338 - loss: 1.1611 - val_accuracy: 0.5674 - val_loss: 1.1009 - learning_rate: 4.0000e-05

# %%
# save training history
with open('training_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
# plot training and validation metrics

plt.figure(figsize=(12, 4))

# plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label = 'Train Accuracy')
plt.plot(history.history['val_accuracy'], label = 'Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()


# plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label = 'Train Loss')
plt.plot(history.history['val_loss'], label = 'Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
